# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pratyush457/week-1-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Provisional lane: Lane 2 — Refresh / Content Opportunity Scoring**
#
# I want to explore how we can identify pages that may be worth reviewing or refreshing first. The goal is to support a practical decision about which pages deserve attention based on their search demand and current performance signals. I chose this lane because the starter dataset contains page-level search and performance data that can help investigate content opportunities. This is a provisional choice and may change as I understand the data better.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Search question:** Which pages should be prioritized for review or refresh based on their search demand and current performance signals?
#
# **Decision:** Decide which pages should receive attention first for a content review or refresh.
#
# **Unit of analysis:** A page.
#
# **Output:** A prioritized list or ranking of pages that may be stronger candidates for review.
#
# **Action:** An SEO or content team could review the prioritized pages and decide whether to update, improve, or leave them unchanged.
#
# **Cost of a wrong recommendation:** A false positive could waste time and resources refreshing a page that did not need attention. A false negative could cause a potentially valuable page to be overlooked.
#
# This is not simply about training a model. The useful outcome is better prioritization of limited content and SEO resources.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### What the data shows
#
# The starter dataset contains **30,000 pages**. The average search volume is **158.88**, showing that the pages have measurable search demand.
#
# All **30,000 pages** in this sample have recorded impressions over the last 90 days.
#
# These numbers make the refresh-prioritization question worth investigating because the dataset contains page-level search and performance signals. However, these numbers alone do not tell us which individual pages should definitely be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/Pratyush457/week-1-/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of pages:", len(df))
print("Average search volume:", round(df["search_volume"].mean(), 2))
print("Pages with impressions:", (df["impressions_90d"] > 0).sum())
# Out:
# Number of pages: 30000
# Average search volume: 158.88
# Pages with impressions: 30000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ### What I can claim
#
# I can describe observed patterns in the starter data and use them as directional signals for deciding which pages may deserve review. The analysis can support prioritization and decision-making.
#
# ### What I cannot claim
#
# I cannot claim that these patterns prove a causal relationship or that refreshing a page will improve its performance. I also cannot claim to predict Google's algorithm or guarantee future rankings, traffic, clicks, or conversions. The result should be treated as decision-support rather than proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Self-check
#
# - [x] I picked a provisional lane.
# - [x] I defined a specific page-level search question.
# - [x] I identified the decision and the action that could follow.
# - [x] I considered the cost of both false positives and false negatives.
# - [x] I used real numbers from the starter dataset.
# - [x] I explained why this is a decision-support problem, not just a model-training exercise.
# - [x] I used careful language and avoided claiming causation or guaranteed outcomes.
